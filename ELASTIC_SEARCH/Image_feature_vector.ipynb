# %% [markdown]
# **Finding Similar Images**

# %%
# get_image_feature_vectors.py
#################################################
# Imports and function definitions
#################################################
# For running inference on the TF-Hub module with Tensorflow
import tensorflow as tf
import tensorflow_hub as hub
# For saving 'feature vectors' into a txt file
import numpy as np
# Glob for reading file names in a folder
import glob
import os.path
#################################################
#################################################
# This function:
# Loads the JPEG image at the given path
# Decodes the JPEG image to a uint8 W X H X 3 tensor
# Resizes the image to 224 x 224 x 3 tensor
# Returns the pre processed image as 224 x 224 x 3 tensor
#################################################
def load_img(path):
# Reads the image file and returns data type of string
 img = tf.io.read_file(path)
# Decodes the image to W x H x 3 shape tensor with type of uint8
 img = tf.io.decode_jpeg(img, channels=3)
# Resizes the image to 224 x 224 x 3 shape tensor
 img = tf.image.resize_with_pad(img, 224, 224)
# Converts the data type of uint8 to float32 by adding a new axis
 # img becomes 1 x 224 x 224 x 3 tensor with data type of float32
 # This is required for the mobilenet model we are using
 img = tf.image.convert_image_dtype(img,tf.float32)[tf.newaxis, ...]
 
 return img
#################################################
# This function:
# Loads the mobilenet model in TF.HUB
# Makes an inference for all images stored in a local folder
# Saves each of the feature vectors in a file
#################################################
def get_image_feature_vectors():
 
 # Definition of module with using tfhub.dev
 module_handle = "https://tfhub.dev/google/imagenet/mobilenet_v2_140_224/feature_vector/4"
 # Loads the module
 module = hub.load(module_handle)
# Loops through all images in a local folder
 for filename in glob.glob('/content/drive/MyDrive/ADM/*.jpg'):
 
  print(filename)
# Loads and pre-process the image
  img = load_img(filename)
# Calculate the image feature vector of the img
  features = module(img)
# Remove single-dimensional entries from the 'features' array  
  feature_set = np.squeeze(features)
 
  # Saves the image feature vectors into a file for later use
  outfile_name = os.path.basename(filename) + ".npz"
 
  out_path = os.path.join('/content/drive/MyDrive/ADM/OUTPUT_VEC/',outfile_name)
# Saves the 'feature_set' to a text file
  np.savetxt(out_path, feature_set, delimiter=',')
get_image_feature_vectors()
# Out:
# /content/drive/MyDrive/ADM/img_000000325.jpg
# /content/drive/MyDrive/ADM/img_000000319.jpg
# /content/drive/MyDrive/ADM/img_0000000274.jpg
# /content/drive/MyDrive/ADM/img_000000125.jpg
# /content/drive/MyDrive/ADM/img_000000119.jpg
# /content/drive/MyDrive/ADM/img_0000000248.jpg
# /content/drive/MyDrive/ADM/img_000000290.jpg
# /content/drive/MyDrive/ADM/img_0000000314.jpg
# /content/drive/MyDrive/ADM/img_000000284.jpg
# /content/drive/MyDrive/ADM/img_0000000328.jpg
# /content/drive/MyDrive/ADM/img_00000003.jpg
# /content/drive/MyDrive/ADM/img_00000017.jpg
# /content/drive/MyDrive/ADM/img_00000016.jpg
# /content/drive/MyDrive/ADM/img_00000002.jpg
# /content/drive/MyDrive/ADM/img_0000000301.jpg
# /content/drive/MyDrive/ADM/img_0000000329.jpg
# /content/drive/MyDrive/ADM/img_000000285.jpg
# /content/drive/MyDrive/ADM/img_000000118.jpg
# /content/drive/MyDrive/ADM/img_000000124.jpg
# /content/drive/MyDrive/ADM/img_000000291.jpg
# /content/drive/MyDrive/ADM/img_0000000249.jpg
# /content/drive/MyDrive/ADM/img_0000000114.jpg
# /content/drive/MyDrive/ADM/img_0000000128.jpg
# /content/drive/MyDrive/ADM/img_000000251.jpg
# /content/drive/MyDrive/ADM/img_000000279.jpg
# /content/drive/MyDrive/ADM/img_000000292.jpg
# /content/drive/MyDrive/ADM/img_000000286.jpg
# /content/drive/MyDrive/ADM/img_0000000302.jpg
# /content/drive/MyDrive/ADM/img_00000015.jpg
# /content/drive/MyDrive/ADM/img_000000245.jpg
# /content/drive/MyDrive/ADM/img_000000137.jpg
# /content/drive/MyDrive/ADM/img_000000240 (1).jpg
# /content/drive/MyDrive/ADM/img_0000000313 (1).jpg
# /content/drive/MyDrive/ADM/img_0000000307 (1).jpg
# /content/drive/MyDrive/ADM/img_00000010 (1).jpg
# /content/drive/MyDrive/ADM/img_00000038 (1).jpg
# /content/drive/MyDrive/ADM/img_00000004 (1).jpg
# /content/drive/MyDrive/ADM/img_00000005 (1).jpg
# /content/drive/MyDrive/ADM/img_00000011 (1).jpg
# /content/drive/MyDrive/ADM/img_00000039 (1).jpg
# /content/drive/MyDrive/ADM/img_0000000306 (1).jpg
# /content/drive/MyDrive/ADM/img_000000123.jpg
# /content/drive/MyDrive/ADM/img_0000000299.jpg
# /content/drive/MyDrive/ADM/img_000000335.jpg
# /content/drive/MyDrive/ADM/img_0000000110.jpg
# /content/drive/MyDrive/ADM/img_000000296.jpg
# /content/drive/MyDrive/ADM/img_000000255.jpg
# /content/drive/MyDrive/ADM/img_000000321.jpg
# /content/drive/MyDrive/ADM/img_000000282.jpg
# /content/drive/MyDrive/ADM/img_000000241.jpg
# /content/drive/MyDrive/ADM/img_0000000306.jpg
# /content/drive/MyDrive/ADM/img_00000039.jpg
# /content/drive/MyDrive/ADM/img_0000000312.jpg
# /content/drive/MyDrive/ADM/img_00000011.jpg
# /content/drive/MyDrive/ADM/img_00000005.jpg
# /content/drive/MyDrive/ADM/img_00000010.jpg
# /content/drive/MyDrive/ADM/img_00000004.jpg
# /content/drive/MyDrive/ADM/img_00000038.jpg
# /content/drive/MyDrive/ADM/img_0000000313.jpg
# /content/drive/MyDrive/ADM/img_0000000307.jpg
# /content/drive/MyDrive/ADM/img_000000240.jpg
# /content/drive/MyDrive/ADM/img_000000297.jpg
# /content/drive/MyDrive/ADM/img_000000283.jpg
# /content/drive/MyDrive/ADM/img_0000000111.jpg
# /content/drive/MyDrive/ADM/img_000000320.jpg
# /content/drive/MyDrive/ADM/img_000000122.jpg
# /content/drive/MyDrive/ADM/img_000000136.jpg
# /content/drive/MyDrive/ADM/img_000000318.jpg
# /content/drive/MyDrive/ADM/img_0000000273.jpg
# /content/drive/MyDrive/ADM/img_0000000267.jpg
# /content/drive/MyDrive/ADM/img_000000324.jpg
# /content/drive/MyDrive/ADM/img_000000287.jpg
# /content/drive/MyDrive/ADM/img_0000000129.jpg
# /content/drive/MyDrive/ADM/img_000000293.jpg
# /content/drive/MyDrive/ADM/img_000000278.jpg
# /content/drive/MyDrive/ADM/img_000000244.jpg
# /content/drive/MyDrive/ADM/img_0000000303.jpg
# /content/drive/MyDrive/ADM/img_00000014.jpg
# /content/drive/MyDrive/ADM/img_00000028.jpg
# /content/drive/MyDrive/ADM/img_00000029.jpg
# /content/drive/MyDrive/ADM/img_00000001.jpg
# /content/drive/MyDrive/ADM/img_00000089.jpg
# /content/drive/MyDrive/ADM/img_0000000349.jpg
# /content/drive/MyDrive/ADM/img_0000000188.jpg
# /content/drive/MyDrive/ADM/img_000000144.jpg
# /content/drive/MyDrive/ADM/img_000000385.jpg
# /content/drive/MyDrive/ADM/img_000000150.jpg
# /content/drive/MyDrive/ADM/img_000000193.jpg
# /content/drive/MyDrive/ADM/img_0000000229.jpg
# /content/drive/MyDrive/ADM/img_000000178.jpg
# /content/drive/MyDrive/ADM/img_0000000201.jpg
# /content/drive/MyDrive/ADM/img_000000185.jpg
# /content/drive/MyDrive/ADM/img_000000191.jpg
# /content/drive/MyDrive/ADM/img_000000378.jpg
# /content/drive/MyDrive/ADM/img_000000344.jpg
# /content/drive/MyDrive/ADM/img_000000218.jpg
# /content/drive/MyDrive/ADM/img_0000000149.jpg
# /content/drive/MyDrive/ADM/img_000000224.jpg
# /content/drive/MyDrive/ADM/img_00000060.jpg
# /content/drive/MyDrive/ADM/img_00000074.jpg
# /content/drive/MyDrive/ADM/img_00000048.jpg
# /content/drive/MyDrive/ADM/img_00000049.jpg
# /content/drive/MyDrive/ADM/img_00000075.jpg
# /content/drive/MyDrive/ADM/img_00000061.jpg
# /content/drive/MyDrive/ADM/img_000000219.jpg
# /content/drive/MyDrive/ADM/img_000000225.jpg
# /content/drive/MyDrive/ADM/img_0000000174.jpg
# /content/drive/MyDrive/ADM/img_0000000148.jpg
# /content/drive/MyDrive/ADM/img_000000190.jpg
# /content/drive/MyDrive/ADM/img_000000345.jpg
# /content/drive/MyDrive/ADM/img_000000379.jpg
# /content/drive/MyDrive/ADM/img_000000184.jpg
# /content/drive/MyDrive/ADM/img_0000000271.jpg
# /content/drive/MyDrive/ADM/img_000000336.jpg
# /content/drive/MyDrive/ADM/img_000000120.jpg
# /content/drive/MyDrive/ADM/img_000000322.jpg
# /content/drive/MyDrive/ADM/img_000000295.jpg
# /content/drive/MyDrive/ADM/img_0000000107.jpg
# /content/drive/MyDrive/ADM/img_000000281.jpg
# /content/drive/MyDrive/ADM/img_0000000113.jpg
# /content/drive/MyDrive/ADM/img_000000256.jpg
# /content/drive/MyDrive/ADM/img_000000242.jpg
# /content/drive/MyDrive/ADM/img_0000000311.jpg
# /content/drive/MyDrive/ADM/img_00000006.jpg
# /content/drive/MyDrive/ADM/img_00000013.jpg
# /content/drive/MyDrive/ADM/img_00000012.jpg
# /content/drive/MyDrive/ADM/img_00000007.jpg
# /content/drive/MyDrive/ADM/img_000000257.jpg
# /content/drive/MyDrive/ADM/img_000000243.jpg
# /content/drive/MyDrive/ADM/img_0000000112.jpg
# /content/drive/MyDrive/ADM/img_0000000310.jpg
# /content/drive/MyDrive/ADM/img_000000280.jpg
# /content/drive/MyDrive/ADM/img_000000294.jpg
# /content/drive/MyDrive/ADM/img_0000000106.jpg
# /content/drive/MyDrive/ADM/img_000000337.jpg
# /content/drive/MyDrive/ADM/img_000000135.jpg
# /content/drive/MyDrive/ADM/img_000000323.jpg
# /content/drive/MyDrive/ADM/img_000000121.jpg
# /content/drive/MyDrive/ADM/img_0000000272.jpg
# /content/drive/MyDrive/ADM/img_0000000270.jpg
# /content/drive/MyDrive/ADM/img_0000000266.jpg
# /content/drive/MyDrive/ADM/img_00000071.jpg
# /content/drive/MyDrive/ADM/img_00000070.jpg
# /content/drive/MyDrive/ADM/img_00000064.jpg
# /content/drive/MyDrive/ADM/img_00000058.jpg
# /content/drive/MyDrive/ADM/img_0000000373.jpg
# /content/drive/MyDrive/ADM/img_0000000367.jpg
# /content/drive/MyDrive/ADM/img_0000000171.jpg
# /content/drive/MyDrive/ADM/img_000000340.jpg
# /content/drive/MyDrive/ADM/img_000000220.jpg
# /content/drive/MyDrive/ADM/img_000000383.jpg
# /content/drive/MyDrive/ADM/img_000000156.jpg
# /content/drive/MyDrive/ADM/img_000000142.jpg
# /content/drive/MyDrive/ADM/img_0000000207.jpg
# /content/drive/MyDrive/ADM/img_000000195.jpg
# /content/drive/MyDrive/ADM/img_000000181.jpg
# /content/drive/MyDrive/ADM/img_0000000213.jpg
# /content/drive/MyDrive/ADM/img_000000140.jpg
# /content/drive/MyDrive/ADM/img_000000197.jpg
# /content/drive/MyDrive/ADM/img_000000183.jpg
# /content/drive/MyDrive/ADM/img_000000381.jpg
# /content/drive/MyDrive/ADM/img_000000356.jpg
# /content/drive/MyDrive/ADM/img_0000000173.jpg
# /content/drive/MyDrive/ADM/img_000000342.jpg
# /content/drive/MyDrive/ADM/img_0000000167.jpg
# /content/drive/MyDrive/ADM/img_000000222.jpg
# /content/drive/MyDrive/ADM/img_00000072.jpg
# /content/drive/MyDrive/ADM/img_000000236.jpg
# /content/drive/MyDrive/ADM/img_00000066.jpg
# /content/drive/MyDrive/ADM/img_00000099.jpg
# /content/drive/MyDrive/ADM/img_00000067.jpg
# /content/drive/MyDrive/ADM/img_00000073.jpg
# /content/drive/MyDrive/ADM/img_00000098.jpg
# /content/drive/MyDrive/ADM/img_000000237.jpg
# /content/drive/MyDrive/ADM/img_0000000370.jpg
# /content/drive/MyDrive/ADM/img_000000223.jpg
# /content/drive/MyDrive/ADM/img_0000000172.jpg
# /content/drive/MyDrive/ADM/img_0000000166.jpg
# /content/drive/MyDrive/ADM/img_000000357.jpg
# /content/drive/MyDrive/ADM/img_000000343.jpg
# /content/drive/MyDrive/ADM/img_000000380.jpg
# /content/drive/MyDrive/ADM/img_0000000210.jpg
# /content/drive/MyDrive/ADM/img_000000182.jpg
# /content/drive/MyDrive/ADM/img_000000141.jpg
# /content/drive/MyDrive/ADM/img_000000155.jpg
# /content/drive/MyDrive/ADM/img_000000196.jpg
# /content/drive/MyDrive/ADM/img_0000000228.jpg
# /content/drive/MyDrive/ADM/img_000000179.jpg
# /content/drive/MyDrive/ADM/img_000000192.jpg
# /content/drive/MyDrive/ADM/img_0000000214.jpg
# /content/drive/MyDrive/ADM/img_000000145.jpg
# /content/drive/MyDrive/ADM/img_000000384.jpg
# /content/drive/MyDrive/ADM/img_0000000374.jpg
# /content/drive/MyDrive/ADM/img_00000062.jpg
# /content/drive/MyDrive/ADM/img_00000077.jpg
# /content/drive/MyDrive/ADM/img_00000063.jpg
# /content/drive/MyDrive/ADM/img_00000088.jpg
# /content/drive/MyDrive/ADM/img_00000076.jpg
# /content/drive/MyDrive/ADM/img_0000000189.jpg
# /content/drive/MyDrive/ADM/img_0000000348.jpg
# /content/drive/MyDrive/ADM/img_000000158.jpg
# /content/drive/MyDrive/ADM/img_0000000231.jpg
# /content/drive/MyDrive/ADM/img_0000000209.jpg
# /content/drive/MyDrive/ADM/img_000000164.jpg
# /content/drive/MyDrive/ADM/img_000000206.jpg
# /content/drive/MyDrive/ADM/img_00000056.jpg
# /content/drive/MyDrive/ADM/img_0000000369.jpg
# /content/drive/MyDrive/ADM/img_00000095.jpg
# /content/drive/MyDrive/ADM/img_00000081.jpg
# /content/drive/MyDrive/ADM/img_000000160.jpg
# /content/drive/MyDrive/ADM/img_00000042.jpg
# /content/drive/MyDrive/ADM/img_00000080.jpg
# /content/drive/MyDrive/ADM/img_00000043.jpg
# /content/drive/MyDrive/ADM/img_00000057.jpg
# /content/drive/MyDrive/ADM/img_0000000354.jpg
# /content/drive/MyDrive/ADM/img_0000000368.jpg
# /content/drive/MyDrive/ADM/img_0000000234.jpg
# /content/drive/MyDrive/ADM/img_000000159.jpg
# /content/drive/MyDrive/ADM/img_00000094.jpg
# /content/drive/MyDrive/ADM/img_000000165.jpg
# /content/drive/MyDrive/ADM/img_0000000208.jpg
# /content/drive/MyDrive/ADM/img_000000359.jpg
# /content/drive/MyDrive/ADM/img_000000365.jpg
# /content/drive/MyDrive/ADM/img_000000211.jpg
# /content/drive/MyDrive/ADM/img_0000000168.jpg
# /content/drive/MyDrive/ADM/img_000000198.jpg
# /content/drive/MyDrive/ADM/img_000000205.jpg
# /content/drive/MyDrive/ADM/img_000000239.jpg
# /content/drive/MyDrive/ADM/img_000000371.jpg
# /content/drive/MyDrive/ADM/img_0000000154.jpg
# /content/drive/MyDrive/ADM/img_00000082.jpg
# /content/drive/MyDrive/ADM/img_00000096.jpg
# /content/drive/MyDrive/ADM/img_00000055.jpg
# /content/drive/MyDrive/ADM/img_00000069.jpg
# /content/drive/MyDrive/ADM/img_00000041.jpg
# /content/drive/MyDrive/ADM/img_00000083.jpg
# /content/drive/MyDrive/ADM/img_00000068.jpg
# /content/drive/MyDrive/ADM/img_00000040.jpg
# /content/drive/MyDrive/ADM/img_00000054.jpg
# /content/drive/MyDrive/ADM/img_00000097.jpg
# /content/drive/MyDrive/ADM/img_000000204.jpg
# /content/drive/MyDrive/ADM/img_000000358.jpg
# /content/drive/MyDrive/ADM/img_0000000169.jpg
# /content/drive/MyDrive/ADM/img_0000000212.jpg
# /content/drive/MyDrive/ADM/img_000000194.jpg
# /content/drive/MyDrive/ADM/img_000000143.jpg
# /content/drive/MyDrive/ADM/img_000000364.jpg
# /content/drive/MyDrive/ADM/img_000000238.jpg
# /content/drive/MyDrive/ADM/img_000000199.jpg
# /content/drive/MyDrive/ADM/img_000000180.jpg
# /content/drive/MyDrive/ADM/img_000000157.jpg
# /content/drive/MyDrive/ADM/img_0000000170.jpg
# /content/drive/MyDrive/ADM/img_000000235.jpg
# /content/drive/MyDrive/ADM/img_000000341.jpg
# /content/drive/MyDrive/ADM/img_00000059.jpg
# /content/drive/MyDrive/ADM/img_0000000366.jpg
# /content/drive/MyDrive/ADM/img_0000000372.jpg
# /content/drive/MyDrive/ADM/img_000000355.jpg
# /content/drive/MyDrive/ADM/img_000000382.jpg
# /content/drive/MyDrive/ADM/img_000000221.jpg
# /content/drive/MyDrive/ADM/img_00000065.jpg
# /content/drive/MyDrive/ADM/img_000000298.jpg
# /content/drive/MyDrive/ADM/img_0000000233.jpg
# /content/drive/MyDrive/ADM/img_000000162.jpg
# /content/drive/MyDrive/ADM/img_000000360.jpg
# /content/drive/MyDrive/ADM/img_000000105.jpg
# /content/drive/MyDrive/ADM/img_000000139.jpg
# /content/drive/MyDrive/ADM/img_0000000254.jpg
# /content/drive/MyDrive/ADM/img_0000000227.jpg
# /content/drive/MyDrive/ADM/img_000000176.jpg
# /content/drive/MyDrive/ADM/img_0000000268.jpg
# /content/drive/MyDrive/ADM/img_0000000151.jpg
# /content/drive/MyDrive/ADM/img_0000000186.jpg
# /content/drive/MyDrive/ADM/img_000000200.jpg
# /content/drive/MyDrive/ADM/img_0000000353.jpg
# /content/drive/MyDrive/ADM/img_0000000347.jpg
# /content/drive/MyDrive/ADM/img_00000087.jpg
# /content/drive/MyDrive/ADM/img_00000044.jpg
# /content/drive/MyDrive/ADM/img_00000093.jpg
# /content/drive/MyDrive/ADM/img_00000078.jpg
# /content/drive/MyDrive/ADM/img_00000050.jpg
# /content/drive/MyDrive/ADM/img_00000051.jpg
# /content/drive/MyDrive/ADM/img_00000086.jpg
# /content/drive/MyDrive/ADM/img_00000045.jpg
# /content/drive/MyDrive/ADM/img_00000079.jpg
# /content/drive/MyDrive/ADM/img_00000092.jpg
# /content/drive/MyDrive/ADM/img_0000000352.jpg
# /content/drive/MyDrive/ADM/img_0000000346.jpg
# /content/drive/MyDrive/ADM/img_0000000187.jpg
# /content/drive/MyDrive/ADM/img_000000375.jpg
# /content/drive/MyDrive/ADM/img_000000215.jpg
# /content/drive/MyDrive/ADM/img_000000361.jpg
# /content/drive/MyDrive/ADM/img_000000163.jpg
# /content/drive/MyDrive/ADM/img_000000177.jpg
# /content/drive/MyDrive/ADM/img_0000000226.jpg
# /content/drive/MyDrive/ADM/img_0000000232.jpg
# /content/drive/MyDrive/ADM/img_0000000230.jpg
# /content/drive/MyDrive/ADM/img_000000175.jpg
# /content/drive/MyDrive/ADM/img_000000161.jpg
# /content/drive/MyDrive/ADM/img_000000377.jpg
# /content/drive/MyDrive/ADM/img_000000363.jpg
# /content/drive/MyDrive/ADM/img_0000000152.jpg
# /content/drive/MyDrive/ADM/img_0000000146.jpg
# /content/drive/MyDrive/ADM/img_0000000350.jpg
# /content/drive/MyDrive/ADM/img_000000203.jpg
# /content/drive/MyDrive/ADM/img_000000217.jpg
# /content/drive/MyDrive/ADM/img_00000090.jpg
# /content/drive/MyDrive/ADM/img_00000046.jpg
# /content/drive/MyDrive/ADM/img_00000047.jpg
# /content/drive/MyDrive/ADM/img_00000084.jpg
# /content/drive/MyDrive/ADM/img_00000053.jpg
# /content/drive/MyDrive/ADM/img_00000052.jpg
# /content/drive/MyDrive/ADM/img_00000085.jpg
# /content/drive/MyDrive/ADM/img_00000091.jpg
# /content/drive/MyDrive/ADM/img_000000216.jpg
# /content/drive/MyDrive/ADM/img_0000000351.jpg
# /content/drive/MyDrive/ADM/img_000000202.jpg
# /content/drive/MyDrive/ADM/img_0000000147.jpg
# /content/drive/MyDrive/ADM/img_000000362.jpg
# /content/drive/MyDrive/ADM/img_0000000153.jpg
# /content/drive/MyDrive/ADM/img_000000376.jpg
# /content/drive/MyDrive/ADM/img_0000000127.jpg
# /content/drive/MyDrive/ADM/img_000000289.jpg
# /content/drive/MyDrive/ADM/img_000000262.jpg
# /content/drive/MyDrive/ADM/img_000000276.jpg
# /content/drive/MyDrive/ADM/img_0000000133.jpg
# /content/drive/MyDrive/ADM/img_000000316.jpg
# /content/drive/MyDrive/ADM/img_0000000247.jpg
# /content/drive/MyDrive/ADM/img_000000100.jpg
# /content/drive/MyDrive/ADM/img_0000000253.jpg
# /content/drive/MyDrive/ADM/img_000000116.jpg
# /content/drive/MyDrive/ADM/img_000000102.jpg
# /content/drive/MyDrive/ADM/img_000000300.jpg
# /content/drive/MyDrive/ADM/img_000000260.jpg
# /content/drive/MyDrive/ADM/img_0000000333.jpg
# /content/drive/MyDrive/ADM/img_0000000131.jpg
# /content/drive/MyDrive/ADM/img_0000000327.jpg
# /content/drive/MyDrive/ADM/img_00000018.jpg
# /content/drive/MyDrive/ADM/img_00000024.jpg
# /content/drive/MyDrive/ADM/img_00000030.jpg
# /content/drive/MyDrive/ADM/img_00000025.jpg
# /content/drive/MyDrive/ADM/img_00000031.jpg
# /content/drive/MyDrive/ADM/img_00000019.jpg
# /content/drive/MyDrive/ADM/img_0000000326.jpg
# /content/drive/MyDrive/ADM/img_0000000332.jpg
# /content/drive/MyDrive/ADM/img_000000275.jpg
# /content/drive/MyDrive/ADM/img_0000000130.jpg
# /content/drive/MyDrive/ADM/img_000000103.jpg
# /content/drive/MyDrive/ADM/img_000000261.jpg
# /content/drive/MyDrive/ADM/img_000000315.jpg
# /content/drive/MyDrive/ADM/img_000000117.jpg
# /content/drive/MyDrive/ADM/img_0000000252.jpg
# /content/drive/MyDrive/ADM/img_0000000246.jpg
# /content/drive/MyDrive/ADM/img_000000339.jpg
# /content/drive/MyDrive/ADM/img_0000000108.jpg
# /content/drive/MyDrive/ADM/img_000000305.jpg
# /content/drive/MyDrive/ADM/img_000000265.jpg
# /content/drive/MyDrive/ADM/img_0000000134.jpg
# /content/drive/MyDrive/ADM/img_000000259.jpg
# /content/drive/MyDrive/ADM/img_00000035.jpg
# /content/drive/MyDrive/ADM/img_00000021.jpg
# /content/drive/MyDrive/ADM/img_00000009.jpg
# /content/drive/MyDrive/ADM/img_00000008.jpg
# /content/drive/MyDrive/ADM/img_00000034.jpg
# /content/drive/MyDrive/ADM/img_000000264.jpg
# /content/drive/MyDrive/ADM/img_000000258.jpg
# /content/drive/MyDrive/ADM/img_00000020.jpg
# /content/drive/MyDrive/ADM/img_0000000109.jpg
# /content/drive/MyDrive/ADM/img_000000338.jpg
# /content/drive/MyDrive/ADM/img_000000304.jpg
# /content/drive/MyDrive/ADM/img_0000000269.jpg
# /content/drive/MyDrive/ADM/img_000000138.jpg
# /content/drive/MyDrive/ADM/img_000000104.jpg
# /content/drive/MyDrive/ADM/img_0000000309.jpg
# /content/drive/MyDrive/ADM/img_00000036.jpg
# /content/drive/MyDrive/ADM/img_00000022.jpg
# /content/drive/MyDrive/ADM/img_00000037.jpg
# /content/drive/MyDrive/ADM/img_0000000334.jpg
# /content/drive/MyDrive/ADM/img_0000000308.jpg
# /content/drive/MyDrive/ADM/img_00000023.jpg
# /content/drive/MyDrive/ADM/img_0000000250.jpg
# /content/drive/MyDrive/ADM/img_000000317.jpg
# /content/drive/MyDrive/ADM/img_000000101.jpg
# /content/drive/MyDrive/ADM/img_000000115.jpg
# /content/drive/MyDrive/ADM/img_0000000126.jpg
# /content/drive/MyDrive/ADM/img_000000277.jpg
# /content/drive/MyDrive/ADM/img_000000263.jpg
# /content/drive/MyDrive/ADM/img_000000288.jpg
# /content/drive/MyDrive/ADM/img_0000000132.jpg
# /content/drive/MyDrive/ADM/img_0000000330.jpg
# /content/drive/MyDrive/ADM/img_00000032.jpg
# /content/drive/MyDrive/ADM/img_00000026.jpg
# /content/drive/MyDrive/ADM/img_00000033.jpg
# /content/drive/MyDrive/ADM/img_00000027.jpg
# /content/drive/MyDrive/ADM/img_0000000331.jpg

# %%
# cluster_image_feature_vectors.py
#################################################
# Imports and function definitions
#################################################
# Numpy for loading image feature vectors from file
import numpy as np
# Time for measuring the process time
import time
# Glob for reading file names in a folder
import glob
import os.path
# json for storing data in json file
import json
# Annoy and Scipy for similarity calculation
from annoy import AnnoyIndex
from scipy import spatial
#################################################
#################################################
# This function reads from 'image_data.json' file
# Looks for a specific 'filename' value
# Returns the product id when product image names are matched
# So it is used to find product id based on the product image name
#################################################
#def match_id(filename):
# with open('/Users/erdemisbilen/Angular/fashionWebScraping
# /jsonFiles/image_data.json') as json_file:
#or file in json_file:
#   seen = json.loads(file)
#for line in seen:
    
#     if filename==line['imageName']:
#      print(line)
#      return line['productId']
#      break
#################################################
#################################################
# This function:
# Reads all image feature vectores stored in /feature-vectors/*.npz
# Adds them all in Annoy Index
# Builds ANNOY index
# Calculates the nearest neighbors and image similarity metrics
# Stores image similarity scores with productID in a json file
#################################################
def cluster():
 start_time = time.time()
 
 print("---------------------------------")
 print ("Step.1 - ANNOY index generation - Started at %s" 
 # %time.ctime())
 print("---------------------------------")
# Defining data structures as empty dict
 file_index_to_file_name = {}
 file_index_to_file_vector = {}
 file_index_to_product_id = {}
# Configuring annoy parameters
 dims = 1792
 n_nearest_neighbors = 20
 trees = 10000
# Reads all file names which stores feature vectors
 allfiles = glob.glob('/content/drive/MyDrive/ADM/OUTPUT_VEC/*.npz')
 
 t = AnnoyIndex(dims, metric='angular')
for file_index, i in enumerate(allfiles):
# Reads feature vectors and assigns them into the file_vector
  file_vector = np.loadtxt(i)
# Assigns file_name, feature_vectors and corresponding product_id
  file_name = os.path.basename(i).split('.')[0]
  file_index_to_file_name[file_index] = file_name
  file_index_to_file_vector[file_index] = file_vector
  file_index_to_product_id[file_index] = match_id(file_name)
# Adds image feature vectors into annoy index
  t.add_item(file_index, file_vector)
print("---------------------------------")
  print("Annoy index     : %s" %file_index)
  print("Image file name : %s" %file_name)
  print("Product id      : %s" 
  # %file_index_to_product_id[file_index])
  print("--- %.2f minutes passed ---------" % ((time.time() -
  start_time)/60))
# Builds annoy index
 t.build(trees)
print ("Step.1 - ANNOY index generation - Finished")
 print ("Step.2 - Similarity score calculation - Started ")
named_nearest_neighbors = []
# Loops through all indexed items
 for i in file_index_to_file_name.keys():
 
  # Assigns master file_name, image feature vectors 
  # and product id values
  master_file_name = file_index_to_file_name[i]
  master_vector = file_index_to_file_vector[i]
  master_product_id = file_index_to_product_id[i]
# Calculates the nearest neighbors of the master item
  nearest_neighbors = t.get_nns_by_item(i, n_nearest_neighbors)
# Loops through the nearest neighbors of the master item
  for j in nearest_neighbors:
   
   print(j)
# Assigns file_name, image feature vectors and 
   # product id values of the similar item
   neighbor_file_name = file_index_to_file_name[j]
   neighbor_file_vector = file_index_to_file_vector[j]
   neighbor_product_id = file_index_to_product_id[j]
# Calculates the similarity score of the similar item
   similarity = 1 - spatial.distance.cosine(master_vector,
   neighbor_file_vector)
rounded_similarity = int((similarity * 10000)) / 10000.0
# Appends master product id with the similarity score
   # and the product id of the similar items
   named_nearest_neighbors.append({
     'similarity': rounded_similarity,
     'master_pi': master_product_id,
     'similar_pi': neighbor_product_id})
print("---------------------------------")
 print("Similarity index       : %s" %i)
 print("Master Image file name : %s" %file_index_to_file_name[i])
 print("Nearest Neighbors.     : %s" %nearest_neighbors)
 print("--- %.2f minutes passed ---------" % ((time.time() -
 start_time)/60))
print ("Step.2 - Similarity score calculation - Finished ")
# Writes the 'named_nearest_neighbors' to a json file
 with open('nearest_neighbors.json', 'w') as out:
 json.dump(named_nearest_neighbors, out)
print ("Step.3 - Data stored in 'nearest_neighbors.json' file ")
 print("--- Prosess completed in %.2f minutes ---------" %
 ((time.time() - start_time)/60))
cluster()
